# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv(r'D:\Unified_Mentor\Working_File\Bird Strikes data.csv',encoding='unicode_escape')

# %%
df.shape
# Out:
# (25558, 29)

# %%
df.head()
# Out:
#    ï»¿Record ID Aircraft: Type                Airport: Name Altitude bin  \
# 0        202152       Airplane                 LAGUARDIA NY    > 1000 ft
# 1        208159       Airplane  DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2        207601       Airplane            LAKEFRONT AIRPORT    < 1000 ft
# 3        215953       Airplane          SEATTLE-TACOMA INTL    < 1000 ft
# 4        219878       Airplane                 NORFOLK INTL    < 1000 ft
#
#   Aircraft: Make/Model Wildlife: Number struck  \
# 0            B-737-400                Over 100
# 1                MD-80                Over 100
# 2                C-500                Over 100
# 3            B-737-400                Over 100
# 4         CL-RJ100/200                Over 100
#
#    Wildlife: Number Struck Actual Effect: Impact to flight  FlightDate  \
# 0                             859         Engine Shut Down  23-11-2000
# 1                             424                      NaN  25-07-2001
# ...

# %%
df.ndim
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25558 entries, 0 to 25557
# Data columns (total 29 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   ï»¿Record ID                             25558 non-null  int64
#  1   Aircraft: Type                           25429 non-null  object
#  2   Airport: Name                            25429 non-null  object
#  3   Altitude bin                             25429 non-null  object
#  4   Aircraft: Make/Model                     25558 non-null  object
#  5   Wildlife: Number struck                  25429 non-null  object
#  6   Wildlife: Number Struck Actual           25558 non-null  int64
#  7   Effect: Impact to flight                 2078 non-null   object
#  8   FlightDate                               25429 non-null  object
#  9   Year                                     25429 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# ï»¿Record ID                                   0
# Aircraft: Type                               129
# Airport: Name                                129
# Altitude bin                                 129
# Aircraft: Make/Model                           0
# Wildlife: Number struck                      129
# Wildlife: Number Struck Actual                 0
# Effect: Impact to flight                   23480
# FlightDate                                   129
# Year                                         129
# Month                                        129
# Effect: Indicated Damage                       0
# Aircraft: Number of engines?                 267
# Aircraft: Airline/Operator                   129
# Origin State                                 449
# When: Phase of flight                        129
# Conditions: Precipitation                  23543
# Remains of wildlife collected?                 0
# Remains of wildlife sent to Smithsonian        0
# ...

# %%
df['Airport: Name'].unique()
# Out:
# array(['LAGUARDIA NY', 'DALLAS/FORT WORTH INTL ARPT', 'LAKEFRONT AIRPORT',
#        ..., 'LAKE PALOURDE BASE HELIPORT', 'CULPEPER REGIONAL ARPT',
#        'PRINCESS JULIANA'], dtype=object)

# %%
df['Altitude bin'].unique()
# Out:
# array(['> 1000 ft', '< 1000 ft', nan], dtype=object)

# %%
df['Wildlife: Number struck'].unique()
# Out:
# array(['Over 100', '2 to 10', nan, '11 to 100', '1'], dtype=object)

# %%
df['Effect: Impact to flight'].unique()
# Out:
# array(['Engine Shut Down', nan, 'Precautionary Landing', 'Other',
#        'Aborted Take-off'], dtype=object)

# %%
df['Origin State'].unique()
# Out:
# array(['New York', 'Texas', 'Louisiana', 'Washington', 'Virginia', nan,
#        'Delaware', 'DC', 'Georgia', 'Florida', 'California', 'Illinois',
#        'Connecticut', 'Missouri', 'Rhode Island', 'Hawaii', 'Arizona',
#        'Tennessee', 'South Carolina', 'South Dakota', 'New Jersey',
#        'Colorado', 'Minnesota', 'Alabama', 'Ohio', 'Wisconsin',
#        'Michigan', 'Massachusetts', 'Alaska', 'North Carolina',
#        'Kentucky', 'Indiana', 'Oregon', 'Pennsylvania', 'New Hampshire',
#        'Arkansas', 'Nevada', 'Mississippi', 'Maryland', 'Maine', 'Quebec',
#        'Idaho', 'British Columbia', 'Utah', 'Nebraska', 'Iowa',
#        'New Mexico', 'West Virginia', 'Oklahoma', 'North Dakota',
#        'Vermont', 'Wyoming', 'Kansas', 'Prince Edward Island', 'Montana',
#        'Puerto Rico', 'Ontario', 'Virgin Islands',
#        'Newfoundland and Labrador', 'Alberta', 'Saskatchewan'],
#       dtype=object)

# %%
df['When: Phase of flight'].unique()
# Out:
# array(['Climb', 'Landing Roll', 'Approach', 'Take-off run', 'Descent',
#        nan, 'Taxi', 'Parked'], dtype=object)

# %%
df.columns
# Out:
# Index(['ï»¿Record ID', 'Aircraft: Type', 'Airport: Name', 'Altitude bin',
#        'Aircraft: Make/Model', 'Wildlife: Number struck',
#        'Wildlife: Number Struck Actual', 'Effect: Impact to flight',
#        'FlightDate', 'Year', 'Month', 'Effect: Indicated Damage',
#        'Aircraft: Number of engines?', 'Aircraft: Airline/Operator',
#        'Origin State', 'When: Phase of flight', 'Conditions: Precipitation',
#        'Remains of wildlife collected?',
#        'Remains of wildlife sent to Smithsonian', 'Remarks', 'Wildlife: Size',
#        'Conditions: Sky', 'Wildlife: Species',
#        'Pilot warned of birds or wildlife?', 'Cost: Total $', 'Cost Group',
#        'Feet above ground', 'Number of people injured', 'Is Aircraft Large?'],
#       dtype='object')

# %%
df1=df.copy()

# %%
df1
# Out:
#        ï»¿Record ID Aircraft: Type                    Airport: Name  \
# 0            202152       Airplane                     LAGUARDIA NY
# 1            208159       Airplane      DALLAS/FORT WORTH INTL ARPT
# 2            207601       Airplane                LAKEFRONT AIRPORT
# 3            215953       Airplane              SEATTLE-TACOMA INTL
# 4            219878       Airplane                     NORFOLK INTL
# ...             ...            ...                              ...
# 25553        321151       Airplane                REDDING MUNICIPAL
# 25554        319677       Airplane                     ORLANDO INTL
# 25555        319680            NaN                              NaN
# 25556        319679       Airplane  DETROIT METRO WAYNE COUNTY ARPT
# 25557        319593       Airplane     ABRAHAM LINCOLN CAPITAL ARPT
#
#       Altitude bin Aircraft: Make/Model Wildlife: Number struck  \
# 0        > 1000 ft            B-737-400                Over 100
# ...

# %%
df1 =df1.dropna(subset=['Aircraft: Type', 'Airport: Name', 'Altitude bin',
       'Aircraft: Make/Model', 'Wildlife: Number struck',
       'Wildlife: Number Struck Actual',
       'FlightDate', 'Year', 'Month', 'Effect: Indicated Damage',
       'Aircraft: Number of engines?', 'Aircraft: Airline/Operator',
       'Origin State', 'When: Phase of flight',
       'Remains of wildlife collected?',
       'Remains of wildlife sent to Smithsonian', 'Wildlife: Size',
       'Conditions: Sky', 'Wildlife: Species',
       'Pilot warned of birds or wildlife?', 'Cost: Total $', 'Cost Group',
       'Feet above ground', 'Number of people injured', 'Is Aircraft Large?'])

# %%
df1.isnull().sum()
# Out:
# ï»¿Record ID                                   0
# Aircraft: Type                                 0
# Airport: Name                                  0
# Altitude bin                                   0
# Aircraft: Make/Model                           0
# Wildlife: Number struck                        0
# Wildlife: Number Struck Actual                 0
# Effect: Impact to flight                   22752
# FlightDate                                     0
# Year                                           0
# Month                                          0
# Effect: Indicated Damage                       0
# Aircraft: Number of engines?                   0
# Aircraft: Airline/Operator                     0
# Origin State                                   0
# When: Phase of flight                          0
# Conditions: Precipitation                  22771
# Remains of wildlife collected?                 0
# Remains of wildlife sent to Smithsonian        0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24747 entries, 0 to 25557
# Data columns (total 29 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   ï»¿Record ID                             24747 non-null  int64
#  1   Aircraft: Type                           24747 non-null  object
#  2   Airport: Name                            24747 non-null  object
#  3   Altitude bin                             24747 non-null  object
#  4   Aircraft: Make/Model                     24747 non-null  object
#  5   Wildlife: Number struck                  24747 non-null  object
#  6   Wildlife: Number Struck Actual           24747 non-null  int64
#  7   Effect: Impact to flight                 1995 non-null   object
#  8   FlightDate                               24747 non-null  object
#  9   Year                                     24747 non-null  float64
# ...

# %%
df1.drop(['Remarks'],axis=1,inplace=True)
# Out:
# C:\Users\suchi\AppData\Local\Temp\ipykernel_20644\705099060.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(['Remarks'],axis=1,inplace=True)

# %%
df1.columns
# Out:
# Index(['ï»¿Record ID', 'Aircraft: Type', 'Airport: Name', 'Altitude bin',
#        'Aircraft: Make/Model', 'Wildlife: Number struck',
#        'Wildlife: Number Struck Actual', 'Effect: Impact to flight',
#        'FlightDate', 'Year', 'Month', 'Effect: Indicated Damage',
#        'Aircraft: Number of engines?', 'Aircraft: Airline/Operator',
#        'Origin State', 'When: Phase of flight', 'Conditions: Precipitation',
#        'Remains of wildlife collected?',
#        'Remains of wildlife sent to Smithsonian', 'Wildlife: Size',
#        'Conditions: Sky', 'Wildlife: Species',
#        'Pilot warned of birds or wildlife?', 'Cost: Total $', 'Cost Group',
#        'Feet above ground', 'Number of people injured', 'Is Aircraft Large?'],
#       dtype='object')

# %%
df1.isnull().sum()
# Out:
# ï»¿Record ID                                   0
# Aircraft: Type                                 0
# Airport: Name                                  0
# Altitude bin                                   0
# Aircraft: Make/Model                           0
# Wildlife: Number struck                        0
# Wildlife: Number Struck Actual                 0
# Effect: Impact to flight                   22752
# FlightDate                                     0
# Year                                           0
# Month                                          0
# Effect: Indicated Damage                       0
# Aircraft: Number of engines?                   0
# Aircraft: Airline/Operator                     0
# Origin State                                   0
# When: Phase of flight                          0
# Conditions: Precipitation                  22771
# Remains of wildlife collected?                 0
# Remains of wildlife sent to Smithsonian        0
# ...

# %%
df1.to_csv(r'D:\Unified_Mentor\Working_File\Bird Strikes data_cleaned.csv',index=False)
